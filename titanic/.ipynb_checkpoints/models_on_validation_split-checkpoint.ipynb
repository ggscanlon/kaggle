# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import graphviz
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression

# %%
#load processed, X, y, test
file_loc = '/Users/gregscanlon/Documents/Kaggle/titanic/'

X = pd.read_excel(file_loc+'X_processed.xlsx',index='PassengerId')
y = pd.read_excel(file_loc+'y_processed.xlsx',index='PassengerId')
test = pd.read_excel(file_loc+'gs_test_processed.xlsx',index='PassengerId')

y.set_index('PassengerId',inplace=True)
X.set_index('PassengerId',inplace=True)
test.set_index('PassengerId',inplace=True)

# %%
#scale data manually - not to gaussian
#adj_fare, Age to 0-1 scale
X['fare_norm'] = X['adj_fare'].divide(X['adj_fare'].max())
X['age_norm'] = X['Age'].divide(X['Age'].max())

X.drop(['adj_fare','Age'],axis=1,inplace=True)

test['fare_norm'] = test['adj_fare'].divide(test['adj_fare'].max())
test['age_norm'] = test['Age'].divide(test['Age'].max())

test.drop(['adj_fare','Age'],axis=1,inplace=True)

# %%
X.shape[1] == test.shape[1], len(X), len(test)
# Out:
# (False, 881, 418)

# %%
X.shape
# Out:
# (881, 36)

# %%
test.shape
# Out:
# (418, 28)

# %%
#validation set
X, X_test, y, y_test = train_test_split(X, y, random_state=42)
len(X), len(X_test)
# Out:
# (660, 221)

# %%
#scale data using sklearn
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)
X_test_scaled = scaler.transform(X_test)

# %%
#logistic regression
clf = LogisticRegression(random_state=0).fit(X, y['Survived'])

print('train score: ',clf.score(X, y['Survived']))

print('test score: ',clf.score(X_test, y_test['Survived']))
# Out:
# train score:  0.8257575757575758
# test score:  0.8280542986425339
# /Users/gregscanlon/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#logistic regression on males only
to_drop = ['Age','name_len','tix_group']



dt_dict = {}


for i in [0,25,39,99]:
    #load processed, X, y, test
    file_loc = '/Users/gregscanlon/Documents/Kaggle/titanic/'

    X = pd.read_excel(file_loc+'X_processed.xlsx',index='PassengerId')
    y = pd.read_excel(file_loc+'y_processed.xlsx',index='PassengerId')
    test = pd.read_excel(file_loc+'gs_test_processed.xlsx',index='PassengerId')

    y.set_index('PassengerId',inplace=True)
    X.set_index('PassengerId',inplace=True)
    test.set_index('PassengerId',inplace=True)
    
    #scale data manually - not to gaussian
    #adj_fare, Age to 0-1 scale
    X['fare_norm'] = X['adj_fare'].divide(X['adj_fare'].max())
    X['age_norm'] = X['Age'].divide(X['Age'].max())

    X.drop(['adj_fare','Age'],axis=1,inplace=True)

    test['fare_norm'] = test['adj_fare'].divide(test['adj_fare'].max())
    test['age_norm'] = test['Age'].divide(test['Age'].max())

    test.drop(['adj_fare','Age'],axis=1,inplace=True)

    X, X_test, y, y_test = train_test_split(X, y, random_state=i)
    
    X_male = X[X.m_f==0]
    y_male = y.loc[X_male.index]
    X_test_male = X_test[X_test.m_f==0]
    y_test_male = y_test.loc[X_test_male.index]
    
    for pclass in [1,2,3]:
        print('PClass: ',pclass)

        X_experiment = X_male[X_male.Pclass==pclass]
        y_experiment = y_male.loc[X_experiment.index]
        X_test_exp = X_test_male[X_test_male.Pclass==pclass]
        y_test_exp = y_test_male.loc[X_test_exp.index]

        clf = LogisticRegression(random_state=0,solver='lbfgs').fit(X_experiment, y_experiment['Survived'])

        dt_dict[pclass] = clf
        print('train score: ',clf.score(X_experiment, y_experiment['Survived']))

        print('test score: ',clf.score(X_test_exp, y_test_exp['Survived']))
# Out:
# PClass:  1
# train score:  0.7311827956989247
# test score:  0.6071428571428571
# PClass:  2
# train score:  0.9146341463414634
# test score:  0.9230769230769231
# PClass:  3
# train score:  0.8888888888888888
# test score:  0.8658536585365854
# PClass:  1
# train score:  0.6823529411764706
# test score:  0.6944444444444444
# PClass:  2
# train score:  0.9302325581395349
# test score:  0.8181818181818182
# PClass:  3
# train score:  0.921875
# test score:  0.7931034482758621
# PClass:  1
# train score:  0.6595744680851063
# test score:  0.5555555555555556
# PClass:  2
# train score:  0.9397590361445783
# test score:  0.84
# PClass:  3
# train score:  0.8814229249011858
# test score:  0.8888888888888888
# PClass:  1
# train score:  0.6224489795918368
# test score:  0.6956521739130435
# PClass:  2
# train score:  0.9259259259259259
# test score:  0.8888888888888888
# PClass:  3
# train score:  0.9
# test score:  0.8313253012048193

# %%
#SVM - LINEAR
from sklearn import svm
clf = svm.SVC(kernel='linear').fit(X, y['Survived'])

print('train score: ',clf.score(X, y['Survived']))

print('test score: ',clf.score(X_test, y_test['Survived']))

# %%
#SVM - LINEAR
from sklearn import svm
clf = svm.SVC(kernel='linear').fit(X_scaled, y['Survived'])

print('train score: ',clf.score(X_scaled, y['Survived']))

print('test score: ',clf.score(X_test_scaled, y_test['Survived']))

# %%
#SVM - RBF
from sklearn import svm
clf = svm.SVC(kernel='rbf').fit(X_scaled, y['Survived'])

print('train score: ',clf.score(X_scaled, y['Survived']))

print('test score: ',clf.score(X_test_scaled, y_test['Survived']))
# Out:
# train score:  0.8592814371257484
# test score:  0.820627802690583

# %%
len(X), len(X_test)
# Out:
# (117, 40)

# %%
from sklearn.neighbors import KNeighborsClassifier

X_male = X[X.m_f==0]
y_male = y.loc[X_male.index]
X_test_male = X_test[X_test.m_f==0]
y_test_male = y_test.loc[X_test_male.index]

k_neigh_dict = {}


for pclass in [1,2,3]:
    print('PClass: ',pclass)
    for i in range(10,20,2):
        X_experiment = X_male[X_male.Pclass==pclass]
        y_experiment = y_male.loc[X_experiment.index]
        X_test_exp = X_test_male[X_test_male.Pclass==pclass]
        y_test_exp = y_test_male.loc[X_test_exp.index]

        clf = KNeighborsClassifier(n_neighbors=i).fit(X_experiment, y_experiment['Survived'])
        
        k_neigh_dict[pclass] = clf
        print('k = ',i,' /train score: ',clf.score(X_experiment, y_experiment['Survived']))

        print('k = ',i,' /test score: ',clf.score(X_test_exp, y_test_exp['Survived']))
# Out:
# PClass:  1
# k =  10  /train score:  0.6632653061224489
# k =  10  /test score:  0.6956521739130435
# k =  12  /train score:  0.6836734693877551
# k =  12  /test score:  0.6956521739130435
# k =  14  /train score:  0.6632653061224489
# k =  14  /test score:  0.6956521739130435
# k =  16  /train score:  0.6632653061224489
# k =  16  /test score:  0.6956521739130435
# k =  18  /train score:  0.673469387755102
# k =  18  /test score:  0.6956521739130435
# PClass:  2
# k =  10  /train score:  0.9382716049382716
# k =  10  /test score:  0.8888888888888888
# k =  12  /train score:  0.9382716049382716
# k =  12  /test score:  0.8888888888888888
# k =  14  /train score:  0.9382716049382716
# k =  14  /test score:  0.8888888888888888
# k =  16  /train score:  0.8395061728395061
# k =  16  /test score:  0.8518518518518519
# k =  18  /train score:  0.8395061728395061
# k =  18  /test score:  0.8518518518518519
# PClass:  3
# k =  10  /train score:  0.9038461538461539
# k =  10  /test score:  0.8313253012048193
# k =  12  /train score:  0.8884615384615384
# k =  12  /test score:  0.8192771084337349
# k =  14  /train score:  0.8807692307692307
# k =  14  /test score:  0.8192771084337349
# k =  16  /train score:  0.8807692307692307
# k =  16  /test score:  0.8072289156626506
# k =  18  /train score:  0.8807692307692307
# k =  18  /test score:  0.8072289156626506

# %%
from sklearn.neighbors import KNeighborsClassifier

X_female = X[X.m_f==1]
y_female = y.loc[X_female.index]
X_test_female = X_test[X_test.m_f==1]
y_test_female = y_test.loc[X_test_female.index]

k_neigh_dict = {}


for pclass in [1,2,3]:
    print('PClass: ',pclass)
    for i in range(10,20,2):
        X_experiment = X_female[X_female.Pclass==pclass]
        y_experiment = y_female.loc[X_experiment.index]
        X_test_exp = X_test_female[X_test_female.Pclass==pclass]
        y_test_exp = y_test_female.loc[X_test_exp.index]

        clf = KNeighborsClassifier(n_neighbors=i).fit(X_experiment, y_experiment['Survived'])
        
        k_neigh_dict[pclass] = clf
        print('k = ',i,' /train score: ',clf.score(X_experiment, y_experiment['Survived']))

        print('k = ',i,' /test score: ',clf.score(X_test_exp, y_test_exp['Survived']))
# Out:
# PClass:  1
# k =  10  /train score:  0.9841269841269841
# k =  10  /test score:  0.9310344827586207
# k =  12  /train score:  0.9841269841269841
# k =  12  /test score:  0.9310344827586207
# k =  14  /train score:  0.9841269841269841
# k =  14  /test score:  0.9310344827586207
# k =  16  /train score:  0.9841269841269841
# k =  16  /test score:  0.9310344827586207
# k =  18  /train score:  0.9841269841269841
# k =  18  /test score:  0.9310344827586207
# PClass:  2
# k =  10  /train score:  0.9615384615384616
# k =  10  /test score:  0.8333333333333334
# k =  12  /train score:  0.9615384615384616
# k =  12  /test score:  0.8333333333333334
# k =  14  /train score:  0.9615384615384616
# k =  14  /test score:  0.8333333333333334
# k =  16  /train score:  0.9615384615384616
# k =  16  /test score:  0.8333333333333334
# k =  18  /train score:  0.9615384615384616
# k =  18  /test score:  0.8333333333333334
# PClass:  3
# k =  10  /train score:  0.6886792452830188
# k =  10  /test score:  0.6285714285714286
# k =  12  /train score:  0.6792452830188679
# k =  12  /test score:  0.6857142857142857
# k =  14  /train score:  0.6698113207547169
# k =  14  /test score:  0.6571428571428571
# k =  16  /train score:  0.6792452830188679
# k =  16  /test score:  0.6571428571428571
# k =  18  /train score:  0.660377358490566
# k =  18  /test score:  0.6

# %%
#Decision Tree on males only
from sklearn import tree
to_drop = ['Age','name_len','tix_group']

X_male = X[X.m_f==0]
y_male = y.loc[X_male.index]
X_test_male = X_test[X_test.m_f==0]
y_test_male = y_test.loc[X_test_male.index]

dt_dict = {}


for pclass in [1,2,3]:
    print('PClass: ',pclass)
    for i in [10,20,50,100,500]:
        X_experiment = X_male[X_male.Pclass==pclass]
        y_experiment = y_male.loc[X_experiment.index]
        X_test_exp = X_test_male[X_test_male.Pclass==pclass]
        y_test_exp = y_test_male.loc[X_test_exp.index]

        clf = tree.DecisionTreeClassifier().fit(X_experiment, y_experiment['Survived'])
        
        dt_dict[pclass] = clf
        print('k = ',i,' /train score: ',clf.score(X_experiment, y_experiment['Survived']))

        print('k = ',i,' /test score: ',clf.score(X_test_exp, y_test_exp['Survived']))
# Out:
# PClass:  1
# k =  10  /train score:  1.0
# k =  10  /test score:  0.6521739130434783
# k =  20  /train score:  1.0
# k =  20  /test score:  0.7391304347826086
# k =  50  /train score:  1.0
# k =  50  /test score:  0.6086956521739131
# k =  100  /train score:  1.0
# k =  100  /test score:  0.6956521739130435
# k =  500  /train score:  1.0
# k =  500  /test score:  0.5217391304347826
# PClass:  2
# k =  10  /train score:  1.0
# k =  10  /test score:  0.7407407407407407
# k =  20  /train score:  1.0
# k =  20  /test score:  0.7037037037037037
# k =  50  /train score:  1.0
# k =  50  /test score:  0.7037037037037037
# k =  100  /train score:  1.0
# k =  100  /test score:  0.6666666666666666
# k =  500  /train score:  1.0
# k =  500  /test score:  0.7037037037037037
# PClass:  3
# k =  10  /train score:  0.9961538461538462
# k =  10  /test score:  0.8192771084337349
# k =  20  /train score:  0.9961538461538462
# k =  20  /test score:  0.8072289156626506
# k =  50  /train score:  0.9961538461538462
# k =  50  /test score:  0.8072289156626506
# k =  100  /train score:  0.9961538461538462
# k =  100  /test score:  0.8072289156626506
# k =  500  /train score:  0.9961538461538462
# k =  500  /test score:  0.7951807228915663

# %%
dot_data = tree.export_graphviz(dt_dict[1], out_file=None, 
                      feature_names=X.columns,  
                      class_names=['Died','Lived'],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
#Decision Tree on males only
from sklearn import tree
X_female = X[X.m_f==1]
y_female = y.loc[X_female.index]
X_test_female = X_test[X_test.m_f==1]
y_test_female = y_test.loc[X_test_female.index]

#drop name_len
clf = tree.DecisionTreeClassifier(max_depth = 10, min_samples_leaf = 10).fit(X_female, y_female['Survived'])

print('train score: ',clf.score(X_female, y_female['Survived']))

print('test score: ',clf.score(X_test_female, y_test_female['Survived']))
# Out:
# train score:  0.8471615720524017
# test score:  0.8

# %%
X_female = X[X.m_f==1]
y_female = y.loc[X_female.index]
X_test_female = X_test[X_test.m_f==1]
y_test_female = y_test.loc[X_test_female.index]


for pclass in [1,2,3]:
    print('PClass: ',pclass)
    for i in [10,20,50,100,500]:
        X_experiment = X_female[X_female.Pclass==pclass]
        y_experiment = y_female.loc[X_experiment.index]
        X_test_exp = X_test_female[X_test_female.Pclass==pclass]
        y_test_exp = y_test_female.loc[X_test_exp.index]

        clf = RandomForestClassifier(n_estimators=i,min_samples_leaf = 5).fit(X_experiment, y_experiment['Survived'])
        
        print('k = ',i,' /train score: ',clf.score(X_experiment, y_experiment['Survived']))

        print('k = ',i,' /test score: ',clf.score(X_test_exp, y_test_exp['Survived']))
# Out:
# PClass:  1
# k =  10  /train score:  0.9545454545454546
# k =  10  /test score:  1.0
# k =  20  /train score:  0.9545454545454546
# k =  20  /test score:  1.0
# k =  50  /train score:  0.9545454545454546
# k =  50  /test score:  1.0
# k =  100  /train score:  0.9545454545454546
# k =  100  /test score:  1.0
# k =  500  /train score:  0.9545454545454546
# k =  500  /test score:  1.0
# PClass:  2
# k =  10  /train score:  0.9814814814814815
# k =  10  /test score:  0.7727272727272727
# k =  20  /train score:  0.9814814814814815
# k =  20  /test score:  0.7727272727272727
# k =  50  /train score:  0.9814814814814815
# k =  50  /test score:  0.7727272727272727
# k =  100  /train score:  0.9814814814814815
# k =  100  /test score:  0.7727272727272727
# k =  500  /train score:  0.9814814814814815
# k =  500  /test score:  0.7727272727272727
# PClass:  3
# k =  10  /train score:  0.8165137614678899
# k =  10  /test score:  0.6857142857142857
# k =  20  /train score:  0.8073394495412844
# k =  20  /test score:  0.7142857142857143
# k =  50  /train score:  0.7706422018348624
# k =  50  /test score:  0.7142857142857143
# k =  100  /train score:  0.8256880733944955
# k =  100  /test score:  0.7142857142857143
# k =  500  /train score:  0.8073394495412844
# k =  500  /test score:  0.7142857142857143

# %%
X_male = X[X.m_f==0]
y_male = y.loc[X_male.index]
X_test_male = X_test[X_test.m_f==0]
y_test_male = y_test.loc[X_test_male.index]


for pclass in [1,2,3]:
    print('PClass: ',pclass)
    for i in [10,20,50,100,500]:
        X_experiment = X_male[X_male.Pclass==pclass]
        y_experiment = y_male.loc[X_experiment.index]
        X_test_exp = X_test_male[X_test_male.Pclass==pclass]
        y_test_exp = y_test_male.loc[X_test_exp.index]

        clf = RandomForestClassifier(n_estimators=i,min_samples_leaf = 5).fit(X_experiment, y_experiment['Survived'])
        
        print('k = ',i,' /train score: ',clf.score(X_experiment, y_experiment['Survived']))

        print('k = ',i,' /test score: ',clf.score(X_test_exp, y_test_exp['Survived']))
# Out:
# PClass:  1
# k =  10  /train score:  0.8488372093023255
# k =  10  /test score:  0.6388888888888888
# k =  20  /train score:  0.7325581395348837
# k =  20  /test score:  0.6944444444444444
# k =  50  /train score:  0.7906976744186046
# k =  50  /test score:  0.6666666666666666
# k =  100  /train score:  0.8255813953488372
# k =  100  /test score:  0.6944444444444444
# k =  500  /train score:  0.7790697674418605
# k =  500  /test score:  0.6666666666666666
# PClass:  2
# k =  10  /train score:  0.8275862068965517
# k =  10  /test score:  0.9047619047619048
# k =  20  /train score:  0.9080459770114943
# k =  20  /test score:  0.9523809523809523
# k =  50  /train score:  0.9195402298850575
# k =  50  /test score:  0.9523809523809523
# k =  100  /train score:  0.9195402298850575
# k =  100  /test score:  0.9523809523809523
# k =  500  /train score:  0.9195402298850575
# k =  500  /test score:  0.9523809523809523
# PClass:  3
# k =  10  /train score:  0.8609022556390977
# k =  10  /test score:  0.9012345679012346
# k =  20  /train score:  0.868421052631579
# k =  20  /test score:  0.9135802469135802
# k =  50  /train score:  0.8646616541353384
# k =  50  /test score:  0.9012345679012346
# k =  100  /train score:  0.868421052631579
# k =  100  /test score:  0.9012345679012346
# k =  500  /train score:  0.8646616541353384
# k =  500  /test score:  0.9012345679012346

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
for i in [10,20,50,100,500]:
    clf = RandomForestClassifier(n_estimators=i,min_samples_leaf = 5).fit(X_male, y_male['Survived'])
    
    print('k = ',i,' /train score: ',clf.score(X_male, y_male['Survived']))

    print('k = ',i,' /test score: ',clf.score(X_test_male, y_test_male['Survived']))
# Out:
# k =  10  /train score:  0.8656036446469249
# k =  10  /test score:  0.8405797101449275
# k =  20  /train score:  0.8724373576309795
# k =  20  /test score:  0.8623188405797102
# k =  50  /train score:  0.876993166287016
# k =  50  /test score:  0.8768115942028986
# k =  100  /train score:  0.8610478359908884
# k =  100  /test score:  0.8478260869565217
# k =  500  /train score:  0.8656036446469249
# k =  500  /test score:  0.8623188405797102

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
for i in [10,20,50,100,500]:
    clf = RandomForestClassifier(n_estimators=i, min_samples_leaf = 5).fit(X_female, y_female['Survived'])
    
    print('k = ',i,' /train score: ',clf.score(X_female, y_female['Survived']))

    print('k = ',i,' /test score: ',clf.score(X_test_female, y_test_female['Survived']))
# Out:
# k =  10  /train score:  0.8995633187772926
# k =  10  /test score:  0.8352941176470589
# k =  20  /train score:  0.8820960698689956
# k =  20  /test score:  0.8235294117647058
# k =  50  /train score:  0.8864628820960698
# k =  50  /test score:  0.8235294117647058
# k =  100  /train score:  0.8908296943231441
# k =  100  /test score:  0.8235294117647058
# k =  500  /train score:  0.8908296943231441
# k =  500  /test score:  0.8352941176470589

# %%
from sklearn.ensemble import AdaBoostClassifier

clf = AdaBoostClassifier(n_estimators=200).fit(X_scaled,y['Survived'])

print('train score: ',clf.score(X_scaled, y['Survived']))

print('test score: ',clf.score(X_test_scaled, y_test['Survived']))
# Out:
# train score:  0.8937125748502994
# test score:  0.8026905829596412

# %%
clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200).fit(X_scaled,y)

print('train score: ',clf.score(X_scaled, y))

print('test score: ',clf.score(X_test_scaled, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-4cf4ebd5758d> in <module>
# ----> 1 clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
#       2                          algorithm="SAMME",
#       3                          n_estimators=200).fit(X_scaled,y)
#       4
#       5 print('train score: ',clf.score(X_scaled, y))
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
clf.feature_importances_
# Out:
# array([4.12876276e-02, 1.23428114e-01, 2.10395965e-02, 1.40467562e-02,
#        9.91751968e-02, 1.02484052e-01, 2.24069742e-02, 1.26077726e-01,
#        1.91036464e-02, 1.57523997e-02, 3.17621059e-02, 3.80428893e-02,
#        1.03491621e-01, 1.81643003e-03, 5.32120500e-03, 5.04979024e-03,
#        4.70848450e-03, 7.19767602e-03, 1.51425034e-03, 1.41917450e-03,
#        8.59506074e-04, 1.77458255e-04, 1.13796514e-02, 8.81818886e-03,
#        7.05618366e-03, 3.52683638e-02, 5.08688653e-05, 1.10430307e-01,
#        3.37807334e-02, 7.05302267e-03])

# %%
importances = clf.feature_importances_
#std = np.std([tree.feature_importances_ for tree in forest.estimators_],
 #            axis=0)
indices = np.argsort(importances)[::-1]

ind_list = []
for i in indices:
    ind_list.append(X.columns[i])

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %s (%f)" % (f + 1, ind_list[f], importances[indices[f]]))

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color="r", align="center")
plt.xticks(range(X.shape[1]), ind_list)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature m_f (0.223071)
# 2. feature Age (0.196561)
# 3. feature adj_fare (0.187648)
# 4. feature name_len (0.183854)
# 5. feature family_size (0.062174)
# 6. feature Pclass (0.056890)
# 7. feature tix_group (0.056611)
# 8. feature embark_num (0.030050)
# 9. feature rare_title (0.003141)

# %%
y_test['Survived'] == clf.predict(X_test)
# Out:
# PassengerId
# 710     True
# 440     True
# 841     True
# 721     True
# 40     False
#        ...
# 881     True
# 426     True
# 102     True
# 200    False
# 425     True
# Name: Survived, Length: 223, dtype: bool

# %%
wrong = y_test.index[y_test['Survived'] != clf.predict(X_test)]
y_test.index[y_test['Survived'] != clf.predict(X_test)]
# Out:
# Int64Index([710, 721, 486, 245, 622, 448,  31, 674, 397, 794, 236, 205,  24,
#             791, 363, 803, 281, 197, 773, 768, 540, 358, 255, 779, 175, 494,
#             166, 389, 713, 339, 287, 513,  97, 293, 276,  79, 579,  66, 600,
#              50, 855, 585, 644, 658, 297,   6, 458,  98, 573, 853,  26,  56,
#              82, 535, 391, 469, 410, 200],
#            dtype='int64', name='PassengerId')

# %%
remerge = X_test.merge(y_test,how='left',left_index=True,right_index=True)
review_incorrect = remerge.loc[wrong]
wrong_male = review_incorrect[review_incorrect.m_f==0]
wrong_female = review_incorrect[review_incorrect.m_f==1]

# %%
for f in ind_list:
    print(f)
# Out:
# m_f
# Age
# adj_fare
# name_len
# family_size
# Pclass
# tix_group
# embark_num
# rare_title

# %%
#split data on 2-4 most important features and eval hist

for f in ind_list:
    if f == 'm_f':
        continue
        
    
    
    ind_list[f], importances[indices[f]]))
